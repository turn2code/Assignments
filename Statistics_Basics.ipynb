# %% [markdown]
# **Assignment Statistics Basics**
# Q1.Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales
# Ans.Data is broadly classified into qualitative and quantitative types based on its characteristics. Each type can be further divided into subcategories based on its scale of measurement: nominal, ordinal, interval, and ratio.
# 1. Qualitative Data
# Qualitative data represents characteristics, attributes, or categories and is non-numerical in nature. It is descriptive and often used to categorize or label objects or phenomena.
#
# Types of Qualitative Data:
# Nominal Scale:
#
# Definition: Data categorized without a specific order.
# Examples:
# Gender (Male, Female, Non-binary)
# Blood type (A, B, AB, O)
# Eye color (Blue, Brown, Green)
# Key Features: No intrinsic ranking or quantitative value.
# Ordinal Scale:
#
# Definition: Data categorized with a meaningful order but without consistent differences between ranks.
# Examples:
# Survey ratings (Poor, Fair, Good, Excellent)
# Educational level (High school, Bachelor's, Master's, Ph.D.)
# Movie rankings (1st, 2nd, 3rd in a competition)
# Key Features: Order matters, but the intervals between categories are not uniform.
# 2. Quantitative Data
# Quantitative data represents numerical information that can be measured or counted. It is used for calculations and statistical analysis.
#
# Types of Quantitative Data:
# Interval Scale:
#
# Definition: Data with a meaningful order and equal intervals between values but no true zero point.
# Examples:
# Temperature in Celsius or Fahrenheit (e.g., 10°C, 20°C, 30°C)
# Calendar years (e.g., 1990, 2000, 2010)
# Key Features: You can add or subtract values, but ratios (e.g., "twice as much") are meaningless because of the lack of an absolute zero.
# Ratio Scale:
#
# Definition: Data with a meaningful order, equal intervals, and a true zero point, allowing for the computation of ratios.
# Examples:
# Height (e.g., 150 cm, 180 cm)
# Weight (e.g., 50 kg, 70 kg)
# Income (e.g., $0, $1000, $2000)
# Time duration (e.g., 0 seconds, 10 seconds, 20 seconds)
# Key Features: You can perform all mathematical operations (addition, subtraction, multiplication, division).

# %% [markdown]
# Q2.What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
# Ans.Measures of Central Tendency
# Measures of central tendency are statistical tools used to describe the central point or typical value in a dataset. The three most common measures are the mean, median, and mode. Each has unique applications and is suited for different types of data and distributions.
# 1. Mean
# The mean (or average) is the sum of all data points divided by the total number of points.
#
# Formula:
# Mean
# =
# ∑
# 𝑥
# 𝑛
# Mean=
# n
# ∑x
# ​
#
# Where:
#
# ∑
# 𝑥
# ∑x is the sum of all data points.
# 𝑛
# n is the number of data points.
# Examples:
# Test scores: If the scores are
# 80
# ,
# 85
# ,
# 90
# ,
# 95
# ,
# 100
# 80,85,90,95,100, the mean is:
# Mean
# =
# 80
# +
# 85
# +
# 90
# +
# 95
# +
# 100
# 5
# =
# 90
# Mean=
# 5
# 80+85+90+95+100
# ​
#  =90
# When to Use:
# Data Type: Quantitative data (interval and ratio scales).
# Suitability:
# Best for symmetric distributions without extreme outliers.
# Used in scenarios where all data points contribute equally, e.g., calculating the average income in a company.
# Limitations:
# Sensitive to outliers. For example, in the dataset
# 10
# ,
# 20
# ,
# 30
# ,
# 1000
# 10,20,30,1000, the mean is
# 265
# 265, which does not represent the typical value well.
# 2. Median
# The median is the middle value when the data is ordered from smallest to largest. If there is an even number of data points, it is the average of the two middle values.
#
# Steps to Calculate:
# Arrange the data in ascending order.
# Find the middle value.
# Examples:
# Dataset 10,20,30,40,50
# 10,20,30,40,50: Median = 30
# 30 (middle value).
# Dataset
# 10
# ,
# 20
# ,
# 30
# ,
# 40
# 10,20,30,40: Median =
# 20
# +
# 30
# 2
# =
# 25
# 2
# 20+30
# ​
#  =25.
# When to Use:
# Data Type: Ordinal, interval, and ratio scales.
# Suitability:
# Best for skewed distributions or when outliers are present.
# Used in real-world contexts like reporting household incomes or property prices (where a few very high values could skew the mean).
# Advantages:
# Not affected by extreme values, providing a better central measure in skewed datasets.
# 3. Mode
# The mode is the value(s) that appear most frequently in a dataset. A dataset can be:
#
# Unimodal: One mode.
# Bimodal: Two modes.
# Multimodal: More than two modes.
# Examples:
# Dataset
# 1
# ,
# 2
# ,
# 2
# ,
# 3
# ,
# 4
# 1,2,2,3,4: Mode =
# 2
# 2 (appears twice).
# Dataset
# 10
# ,
# 20
# ,
# 20
# ,
# 30
# ,
# 30
# ,
# 40
# 10,20,20,30,30,40: Modes =
# 20
# 20 and
# 30
# 30 (bimodal).
# When to Use:
# Data Type: Nominal, ordinal, interval, and ratio scales.
# Suitability:
# Best for categorical data, e.g., finding the most popular color in a survey (red, blue, red, green → Mode = red).
# Useful when the most frequent occurrence is the focus, such as determining the most common product size sold.
# Limitations:
# Not always representative of the data when the dataset has multiple modes or when all values occur with equal frequency.
# Choosing the Right Measure
# Use the mean when data is symmetric and there are no significant outliers.
# Use the median for skewed data or when outliers are present.
# Use the mode for categorical data or when the most frequent value is of interest.

# %% [markdown]
# Q3.Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
# Ans.Concept of Dispersion
# Dispersion refers to the extent to which data points in a dataset differ from one another or from a central value (like the mean). It provides insights into the variability or spread of the data. A dataset with low dispersion has values close to the central tendency, while a dataset with high dispersion has values spread widely.
# Importance of Dispersion
# Understanding Variability: Shows how consistent or inconsistent the data is.
# Comparison: Helps compare the spread of different datasets.
# Data Analysis: Provides a basis for further statistical calculations like confidence intervals and hypothesis testing.
# Measures of Dispersion
# Two common measures of dispersion are variance and standard deviation, which quantify how much the data varies around the mean.
#
# 1. Variance
# Variance measures the average of the squared differences between each data point and the mean. It emphasizes larger deviations due to squaring, making it useful for detecting large variability.
#
# Formula for Variance:
# Population Variance:
# 𝜎
# 2
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# σ
# 2
#  =
# N
# ∑(x
# i
# ​
#  −μ)
# 2
#
# ​
#
# Sample Variance:
# 𝑠
# 2
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# s
# 2
#  =
# n−1
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#  : Individual data points
# 𝜇
# μ: Population mean
# 𝑥
# ˉ
# x
# ˉ
#  : Sample mean
# 𝑁
# N: Population size
# 𝑛
# n: Sample size
# Example:
# For a dataset
# 2
# ,
# 4
# ,
# 6
# ,
# 8
# 2,4,6,8:
#
# Find the mean (
# 𝑥
# ˉ
# x
# ˉ
#  ):
# 𝑥
# ˉ
# =
# 2
# +
# 4
# +
# 6
# +
# 8
# 4
# =
# 5
# x
# ˉ
#  =
# 4
# 2+4+6+8
# ​
#  =5
# Calculate squared deviations:
# (
# 2
# −
# 5
# )
# 2
# ,
# (
# 4
# −
# 5
# )
# 2
# ,
# (
# 6
# −
# 5
# )
# 2
# ,
# (
# 8
# −
# 5
# )
# 2
# =
# 9
# ,
# 1
# ,
# 1
# ,
# 9
# (2−5)
# 2
#  ,(4−5)
# 2
#  ,(6−5)
# 2
#  ,(8−5)
# 2
#  =9,1,1,9
# Find the variance:
# 𝑠
# 2
# =
# 9
# +
# 1
# +
# 1
# +
# 9
# 4
# −
# 1
# =
# 20
# 3
# ≈
# 6.67
# s
# 2
#  =
# 4−1
# 9+1+1+9
# ​
#  =
# 3
# 20
# ​
#  ≈6.67
# Key Features:
# Always non-negative because deviations are squared.
# In units squared of the original data (e.g., if the data is in meters, variance is in square meters).
# 2. Standard Deviation
# Standard deviation (SD) is the square root of the variance, which returns the measure to the same unit as the original data. It provides an intuitive sense of the average spread of the data points around the mean.
#
# Formula for Standard Deviation:
# Population SD:
# 𝜎
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# σ=
# N
# ∑(x
# i
# ​
#  −μ)
# 2
#
# ​
#
# ​
#
# Sample SD:
# 𝑠
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# s=
# n−1
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# ​
#
# Example:
# Using the variance
# 𝑠
# 2
# ≈
# 6.67
# s
# 2
#  ≈6.67 from the earlier example:
#
# 𝑠
# =
# 6.67
# ≈
# 2.58
# s=
# 6.67
# ​
#  ≈2.58
# Key Features:
# In the same units as the original data.
# Indicates the average distance of data points from the mean.
# How Variance and Standard Deviation Measure Spread
# Sensitivity to Spread:
#
# Both measures consider every data point.
# Larger deviations from the mean contribute significantly (due to squaring in variance).
# Identifying Homogeneity:
#
# A smaller variance or SD indicates data points are closer to the mean (low variability).
# A larger variance or SD indicates data points are more spread out (high variability).
# Comparison:
#
# Variance is useful in theoretical and statistical derivations (e.g., ANOVA).
# Standard deviation is more practical for interpreting real-world data.
# Application Scenarios
# Low Variance/SD: Consistent manufacturing quality where product dimensions rarely deviate.
# High Variance/SD: Financial market returns, where large fluctuations are expected.
# By understanding variance and standard deviation, statisticians can effectively measure, interpret, and compare data variability.

# %% [markdown]
# Q4. What is a box plot, and what can it tell you about the distribution of data?
# Ans.A box plot (or box-and-whisker plot) is a graphical representation of a dataset that provides a visual summary of its central tendency, spread, and potential outliers. It divides data into quartiles, highlighting the middle 50% of the data (interquartile range, or IQR) and showing the overall distribution.
#
# Components of a Box Plot
# Median (Q2):
#
# The middle value of the dataset when arranged in ascending order.
# Shown as a line inside the box.
# Quartiles:
#
# Q1 (First Quartile): The median of the lower half (25th percentile).
# Q3 (Third Quartile): The median of the upper half (75th percentile).
# Interquartile Range (IQR):
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Represents the middle 50% of the data.
# Whiskers:
#
# Extend from the box to the smallest and largest values within
# 1.5
# ×
# IQR
# 1.5×IQR from Q1 and Q3.
# Values beyond this range are considered outliers.
# Outliers:
#
# Data points outside the whiskers are plotted as individual dots or marks.
# What a Box Plot Reveals About Data
# Central Tendency:
#
# The median line inside the box shows the central value of the dataset.
# Spread/Variability:
#
# The width of the box (IQR) indicates the variability in the middle 50% of the data.
# Longer whiskers suggest greater spread outside the middle 50%.
# Symmetry or Skewness:
#
# If the median is closer to Q1 or Q3, the data is skewed.
# Symmetrical boxes indicate a roughly normal distribution.
# Presence of Outliers:
#
# Points outside the whiskers signal potential outliers, which may require further investigation.
# Range:
#
# The total length from the smallest to the largest whisker shows the overall range of the data (excluding outliers).
# Example Interpretation
# Imagine a box plot for test scores:
#
# Median: 75
# Q1: 65, Q3: 85 (IQR = 20)
# Whiskers: 50 (minimum) and 95 (maximum)
# Outliers: 40 and 100
# Insights:
# Central Tendency: The median score is 75.
# Spread: Most scores lie between 65 and 85, with a moderate spread.
# Skewness: The median is centered, suggesting a symmetrical distribution.
# Outliers: Scores of 40 and 100 are unusually low and high, respectively.
# Advantages of a Box Plot
# Summarizes large datasets visually.
# Clearly identifies outliers.
# Provides a quick view of distribution, spread, and skewness.
# Limitations
# Does not show the frequency or density of data within quartiles.
# Limited detail compared to a histogram or density plot.
# When to Use a Box Plot
# Comparing distributions across multiple datasets.
# Identifying outliers in a dataset.
# Summarizing data for exploratory data analysis (EDA).
# Box plots are versatile tools for gaining quick insights into the distribution and spread of data, making them invaluable for statistical and data analysis tasks

# %% [markdown]
# Q5. Discuss the role of random sampling in making inferences about populations.
# Ans.The Role of Random Sampling in Making Inferences About Populations
# Random sampling is a fundamental method in statistics that allows researchers to select a subset (sample) from a larger population in a way that ensures every member of the population has an equal chance of being chosen. This method plays a crucial role in drawing reliable inferences about the population as a whole.
#
# Why Use Random Sampling?
# Representativeness:
#
# A random sample accurately reflects the characteristics of the population.
# Ensures that no subgroup is systematically overrepresented or underrepresented.
# Minimizes Bias:
#
# Random sampling reduces selection bias, which occurs when certain individuals or groups are more likely to be included in the sample.
# Facilitates Generalization:
#
# Results from a random sample can be generalized to the entire population, allowing researchers to make valid conclusions.
# Steps in Random Sampling
# Define the Population: Clearly specify the group from which the sample will be drawn.
#
# Example: All students in a university.
# Determine the Sample Size: Choose an appropriate size to balance accuracy and feasibility.
#
# Larger samples reduce sampling error but require more resources.
# Use a Random Selection Method:
#
# Simple random sampling (e.g., drawing names from a hat or using random number generators).
# Systematic sampling (selecting every nth individual after a random starting point).
# How Random Sampling Supports Inferences
# Estimation of Population Parameters:
#
# Random samples provide estimates of population parameters (e.g., mean, proportion).
# Example: Estimating the average income of a city by surveying a random sample of households.
# Reduction of Sampling Error:
#
# Sampling error refers to the difference between the sample statistic and the true population parameter.
# Random sampling helps minimize this error, especially with larger samples.
# Basis for Statistical Tests:
#
# Random sampling allows the use of inferential statistical methods, such as hypothesis testing and confidence intervals.
# Example: Testing whether a new teaching method improves student performance based on a random sample of students.
# Law of Large Numbers:
#
# As the sample size increases, the sample statistic converges to the true population parameter, improving the reliability of inferences.
# Support for Probabilistic Models:
#
# Random sampling ensures that probabilistic assumptions underlying many statistical methods (e.g., independence, normality) are met.
# Challenges in Random Sampling
# Nonresponse Bias:
#
# If selected individuals do not respond, the sample may become less representative.
# Mitigation: Follow-up with nonrespondents or adjust weights during analysis.
# Sampling Frame Issues:
#
# The sampling frame (list of all members of the population) must be accurate and complete.
# Example: Excluding unregistered voters from a political survey may skew results.
# Practical Constraints:
#
# Time, cost, and accessibility can limit the feasibility of truly random sampling.
# Examples of Random Sampling in Practice
# Political Polls:
#
# A random sample of voters is surveyed to predict election outcomes.
# Medical Research:
#
# Clinical trials randomly select participants to test new treatments, ensuring results are unbiased and generalizable.
# Market Research:
#
# Businesses survey random samples of customers to gauge satisfaction or preferences.

# %% [markdown]
# Q6.Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# Ans.Concept of Skewness
# Skewness is a statistical measure that describes the asymmetry of a dataset's distribution. It indicates whether the data points are concentrated more on one side of the mean compared to the other, reflecting how "tailed" the distribution is.
#
# A perfectly symmetrical distribution (e.g., a normal distribution) has a skewness of 0.
# Non-zero skewness suggests an imbalance in the distribution of data.
# Types of Skewness
# Positive Skew (Right-Skewed):
#
# The tail on the right side (greater values) is longer or heavier.
# Most data points are concentrated on the left of the mean.
# Mean > Median > Mode
# Example: Income distribution, where a few people earn extremely high amounts compared to the majority.
# Negative Skew (Left-Skewed):
#
# The tail on the left side (lower values) is longer or heavier.
# Most data points are concentrated on the right of the mean.
# Mean < Median < Mode
# Example: Age of retirement, where most people retire at older ages, with fewer retiring early.
# Zero Skew (Symmetrical):
#
# The data is evenly distributed around the mean.
# Mean = Median = Mode
# Example: Heights of individuals in a large population, which often follow a normal distribution.
# How to Measure Skewness
# Formula:
#
# Skewness
# =
# 𝑛
# (
# 𝑛
# −
# 1
# )
# (
# 𝑛
# −
# 2
# )
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# 𝑠
# )
# 3
# Skewness=
# (n−1)(n−2)
# n
# ​
#  ∑(
# s
# x
# i
# ​
#  −
# x
# ˉ
#
# ​
#  )
# 3
#
# Where:
#
# 𝑛
# n: Number of data points
# 𝑥
# 𝑖
# x
# i
# ​
#  : Individual data point
# 𝑥
# ˉ
# x
# ˉ
#  : Mean
# 𝑠
# s: Standard deviation
# Interpretation:
#
# Skewness > 0: Positive skew.
# Skewness < 0: Negative skew.
# Skewness = 0: Symmetrical distribution.
# Effects of Skewness on Data Interpretation
# Central Tendency:
#
# In skewed distributions, the mean is pulled in the direction of the skewed tail, making it less representative of the "typical" value.
# The median is a more robust measure of central tendency in such cases.
# Spread and Outliers:
#
# Skewed distributions often contain extreme values (outliers) in the tail, affecting measures like variance and standard deviation.
# Inferential Analysis:
#
# Many statistical tests (e.g., t-tests, ANOVA) assume normality. High skewness violates this assumption, potentially leading to incorrect conclusions.
# Data transformation (e.g., logarithmic or square root) may be needed to reduce skewness before analysis.
# Real-World Decision-Making:
#
# Positive skew in income data indicates economic inequality.
# Negative skew in healthcare response times may show most patients are treated quickly, with rare delays.
# Examples of Skewness in Real Life
# Positive Skew:
# Wealth distribution: A small proportion of people hold a large share of total wealth.
# Housing prices: Most houses are moderately priced, but a few are extremely expensive.
# Negative Skew:
# Test scores: In an easy exam, most students score high, with few scoring low.
# Lifespan: Most people live to old age, with fewer dying young.

# %% [markdown]
# Q7. What is the interquartile range (IQR), and how is it used to detect outliers?
# Ans.Interquartile Range (IQR): Definition
# The interquartile range (IQR) is a measure of statistical dispersion that represents the range of the middle 50% of a dataset. It is calculated as the difference between the third quartile (
# 𝑄
# 3
# Q3) and the first quartile (
# 𝑄
# 1
# Q1):
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# 𝑄
# 1
# Q1 (First Quartile): The median of the lower half of the dataset (25th percentile).
# 𝑄
# 3
# Q3 (Third Quartile): The median of the upper half of the dataset (75th percentile).
# The IQR highlights the spread of the central portion of the data, excluding outliers and extremes.
#
# Steps to Calculate IQR
# Arrange the data in ascending order.
# Identify
# 𝑄
# 1
# Q1 (25th percentile) and
# 𝑄
# 3
# Q3 (75th percentile).
# Subtract
# 𝑄
# 1
# Q1 from
# 𝑄
# 3
# Q3:
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1.
# Example:
# Given the dataset:
# 2
# ,
# 4
# ,
# 6
# ,
# 8
# ,
# 10
# ,
# 12
# ,
# 14
# 2,4,6,8,10,12,14:
#
# 𝑄
# 1
# =
# 4
# Q1=4,
# 𝑄
# 3
# =
# 12
# Q3=12.
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# =
# 12
# −
# 4
# =
# 8
# IQR=Q3−Q1=12−4=8.
# Using IQR to Detect Outliers
# Outliers are data points that lie significantly outside the typical range of the dataset. The IQR helps identify these outliers using the following rule:
#
# Lower Bound:
#
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Q1−1.5×IQR
# Upper Bound:
#
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Q3+1.5×IQR
# Any data points outside these bounds are considered outliers.
#
# Example:
# For the dataset
# 2
# ,
# 4
# ,
# 6
# ,
# 8
# ,
# 10
# ,
# 12
# ,
# 14
# 2,4,6,8,10,12,14:
#
# IQR
# =
# 8
# IQR=8.
# Lower Bound:
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# =
# 4
# −
# 1.5
# ×
# 8
# =
# −
# 8
# Q1−1.5×IQR=4−1.5×8=−8.
# Upper Bound:
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# =
# 12
# +
# 1.5
# ×
# 8
# =
# 24
# Q3+1.5×IQR=12+1.5×8=24.
# Outliers:
#
# No values below
# −
# 8
# −8 or above
# 24
# 24, so this dataset has no outliers.
# Applications of IQR
# Outlier Detection:
#
# Used in box plots, where whiskers represent the 1.5 × IQR range, and points beyond are plotted as outliers.
# Important for identifying extreme values that may skew analysis.
# Robust Summary of Spread:
#
# Unlike standard deviation, the IQR is unaffected by outliers or extreme values.
# Useful for non-normal distributions.
# Data Cleaning:
#
# Helps determine whether outliers should be excluded or addressed (e.g., through transformation or capping).
# Comparison of Variability:
#
# Enables comparison of spreads across datasets without being influenced by outliers.
# Advantages of Using IQR
# Resistant to outliers and extreme values.
# Provides a focused view of the middle range of data.
# Simple to calculate and interpret.
# Limitations
# Does not give information about the entire dataset (e.g., the tails).
# Less informative for small datasets where quartile calculation may be less precise.

# %% [markdown]
# Q8.Discuss the conditions under which the binomial distribution is used.
# Ans.Binomial Distribution: Definition
# The binomial distribution is a discrete probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has two possible outcomes (success or failure).
#
# The probability mass function (PMF) of a binomial distribution is given by:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Where:
#
# 𝑛
# n: Number of trials.
# 𝑘
# k: Number of successes.
# 𝑝
# p: Probability of success in each trial.
# (
# 1
# −
# 𝑝
# )
# (1−p): Probability of failure in each trial.
# (
# 𝑛
# 𝑘
# )
# =
# 𝑛
# !
# 𝑘
# !
# (
# 𝑛
# −
# 𝑘
# )
# !
# (
# k
# n
# ​
#  )=
# k!(n−k)!
# n!
# ​
#  : Number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials.
# Conditions for Using the Binomial Distribution
# The binomial distribution is applicable under the following conditions:
#
# Fixed Number of Trials (
# 𝑛
# n):
#
# The total number of trials is predetermined and constant.
# Example: Tossing a coin 10 times.
# Binary Outcomes:
#
# Each trial has exactly two possible outcomes: success or failure.
# Example: In a survey, the response could be "Yes" (success) or "No" (failure).
# Independent Trials:
#
# The outcome of one trial does not influence the outcome of any other trial.
# Example: Flipping a coin multiple times.
# Constant Probability of Success (
# 𝑝
# p):
#
# The probability of success remains the same for each trial.
# Example: The probability of rolling a 6 on a fair die (
# 𝑝
# =
# 1
# /
# 6
# p=1/6) does not change from one roll to the next.
# Discrete Variable:
#
# The variable of interest (e.g., number of successes) must be discrete.
# Examples of Situations for Binomial Distribution
# Tossing Coins:
#
# Number of heads in 10 coin tosses (
# 𝑝
# =
# 0.5
# p=0.5).
# Survey Responses:
#
# Number of people who say "Yes" in a sample of 100 respondents (
# 𝑝
# =
# 0.7
# p=0.7).
# Defective Products:
#
# Number of defective items in a batch of 20 items (
# 𝑝
# =
# 0.1
# p=0.1).
# Medical Trials:
#
# Number of patients who recover after a new treatment in a group of 50 patients (
# 𝑝
# =
# 0.8
# p=0.8).
# Key Characteristics of the Binomial Distribution
# Mean:
#
# 𝜇
# =
# 𝑛
# ⋅
# 𝑝
# μ=n⋅p
# Variance:
#
# 𝜎
# 2
# =
# 𝑛
# ⋅
# 𝑝
# ⋅
# (
# 1
# −
# 𝑝
# )
# σ
# 2
#  =n⋅p⋅(1−p)
# Shape:
#
# If
# 𝑝
# =
# 0.5
# p=0.5, the distribution is symmetrical.
# If
# 𝑝
# <
# 0.5
# p<0.5, the distribution is skewed to the right.
# If
# 𝑝
# >
# 0.5
# p>0.5, the distribution is skewed to the left.
# When Not to Use the Binomial Distribution
# If any of the conditions are violated, the binomial distribution is not appropriate:
#
# Trials are not independent:
#
# Example: Drawing cards from a deck without replacement.
# Variable outcomes:
#
# Example: Rolling a die where there are six possible outcomes.
# Varying probabilities:
#
# Example: In a batch of products, if defective items are not replaced,
# 𝑝
# p changes over successive trials.
# Extensions
# If the number of trials (
# 𝑛
# n) is very large and the probability of success (
# 𝑝
# p) is small, the binomial distribution can be approximated by:
#
# Poisson Distribution:
# Used when
# 𝑛
# n is large and
# 𝑝
# p is small (
# 𝜆
# =
# 𝑛
# ⋅
# 𝑝
# λ=n⋅p).
# Normal Distribution:
# Used when
# 𝑛
# n is large and
# 𝑝
# p is not too close to 0 or 1 (using continuity correction).

# %% [markdown]
# Q9.Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
# Ans.Properties of the Normal Distribution
# The normal distribution (also known as the Gaussian distribution) is a continuous probability distribution widely used in statistics due to its natural occurrence in many phenomena. Its probability density function is defined as:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝜎
# 2
# 𝜋
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x)=
# σ
# 2π
# ​
#
# 1
# ​
#  e
# −
# 2σ
# 2
#
# (x−μ)
# 2
#
# ​
#
#
# Where:
#
# 𝑥
# x: A random variable.
# 𝜇
# μ: Mean (center of the distribution).
# 𝜎
# σ: Standard deviation (spread of the distribution).
# Key Properties
# Symmetry:
#
# The normal distribution is symmetric about the mean (
# 𝜇
# μ).
# The left and right halves are mirror images.
# Bell Shape:
#
# The curve is bell-shaped, peaking at the mean and tapering off symmetrically.
# Mean, Median, and Mode:
#
# All three measures of central tendency are equal and located at the center (
# 𝜇
# μ).
# Asymptotic Nature:
#
# The tails of the distribution approach, but never touch, the horizontal axis.
# Defined by Mean and Standard Deviation:
#
# The shape and location are entirely determined by
# 𝜇
# μ and
# 𝜎
# σ.
# Total Area Equals 1:
#
# The area under the curve is always 1, representing 100% probability.
# Inflection Points:
#
# Occur at
# 𝜇
# −
# 𝜎
# μ−σ and
# 𝜇
# +
# 𝜎
# μ+σ, where the curvature changes.
# Universal Applicability:
#
# Many natural and measurement phenomena (e.g., heights, test scores) approximate a normal distribution.
# The Empirical Rule (68-95-99.7 Rule)
# The empirical rule provides a way to estimate the spread of data in a normal distribution in terms of standard deviations from the mean:
#
# 68% of Data:
#
# Falls within 1 standard deviation (
# 𝜇
# ±
# 𝜎
# μ±σ).
# Example: If
# 𝜇
# =
# 100
# μ=100 and
# 𝜎
# =
# 15
# σ=15, about 68% of the data lies between 85 and 115.
# 95% of Data:
#
# Falls within 2 standard deviations (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ).
# Example: About 95% of the data lies between 70 and 130.
# 99.7% of Data:
#
# Falls within 3 standard deviations (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ).
# Example: About 99.7% of the data lies between 55 and 145.
# Applications of the Empirical Rule
# Outlier Detection:
#
# Data points beyond
# 3
# 𝜎
# 3σ are considered extreme outliers.
# Quality Control:
#
# In manufacturing, processes are often monitored to ensure 99.7% of products meet specifications.
# Standardized Testing:
#
# Scores in tests like IQ or SAT are often analyzed using the normal distribution to estimate population percentiles.
# Prediction and Decision-Making:
#
# The empirical rule helps estimate probabilities and assess risks based on standard deviations.
# Graphical Representation of the Empirical Rule
# A bell-shaped curve with the following percentages marked:
# 68% within
# 𝜇
# ±
# 𝜎
# μ±σ.
# 95% within
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ.
# 99.7% within
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ.
# Limitations
# The empirical rule applies only to normal distributions. It may not accurately describe datasets with skewed or multimodal distributions.
# Extreme outliers can distort the estimation of standard deviation and mean.

# %% [markdown]
# Q10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
# Ans.Real-Life Example of a Poisson Process
# A Poisson process is a statistical process that models the occurrence of events happening independently at a constant average rate over a fixed period of time or space. The key characteristics of a Poisson process are:
#
# Events happen independently.
# The average number of events is constant over time or space.
# Events cannot occur simultaneously (i.e., there is only one event at a time).
# Example: Arrivals of Customers at a Bank
# Imagine a bank where customers arrive randomly, and on average, 3 customers arrive per hour. The arrival of customers follows a Poisson process because:
#
# The arrivals happen independently of each other.
# The average rate of arrival (3 customers per hour) is constant.
# There is no limit to the number of customers that can arrive in a given time period, but only one customer can arrive at any given moment.
# Now, we want to calculate the probability that exactly 5 customers will arrive in the next hour.
#
# Poisson Distribution Formula
# The Poisson probability mass function (PMF) is given by the formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# Where:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# P(X=k) is the probability of observing exactly
# 𝑘
# k events.
# 𝜆
# λ is the average rate of occurrence (mean number of events in the time period).
# 𝑘
# k is the number of events (in this case, customers) we are interested in.
# 𝑒
# e is Euler's number (
# 𝑒
# ≈
# 2.71828
# e≈2.71828).
# Step-by-Step Calculation
# Given:
# 𝜆
# =
# 3
# λ=3 customers per hour (mean number of arrivals).
# 𝑘
# =
# 5
# k=5 customers (we want to know the probability of 5 customers arriving).
# Using the Poisson formula:
#
# 𝑃
# (
# 𝑋
# =
# 5
# )
# =
# 3
# 5
# 𝑒
# −
# 3
# 5
# !
# P(X=5)=
# 5!
# 3
# 5
#  e
# −3
#
# ​
#
# 1. Calculate
# 3
# 5
# 3
# 5
#  :
# 3
# 5
# =
# 243
# 3
# 5
#  =243
# 2. Calculate
# 𝑒
# −
# 3
# e
# −3
#  :
# 𝑒
# −
# 3
# ≈
# 0.0498
# e
# −3
#  ≈0.0498
# 3. Calculate
# 5
# !
# 5! (5 factorial):
# 5
# !
# =
# 5
# ×
# 4
# ×
# 3
# ×
# 2
# ×
# 1
# =
# 120
# 5!=5×4×3×2×1=120
# 4. Plug the values into the formula:
# 𝑃
# (
# 𝑋
# =
# 5
# )
# =
# 243
# ×
# 0.0498
# 120
# P(X=5)=
# 120
# 243×0.0498
# ​
#
# 5. Simplify:
# 𝑃
# (
# 𝑋
# =
# 5
# )
# ≈
# 12.1
# 120
# ≈
# 0.1008
# P(X=5)≈
# 120
# 12.1
# ​
#  ≈0.1008
# Conclusion
# The probability that exactly 5 customers will arrive at the bank in the next hour is approximately 0.1008 or 10.08%.
#
# Interpretation
# This means that, based on the Poisson distribution, there is about a 10.08% chance that exactly 5 customers will arrive at the bank in the next hour, assuming the average arrival rate is 3 customers per hour.
# This can be useful for managing resources, like staffing levels, and ensuring the bank can handle customer traffic efficiently.

# %% [markdown]
# Q11. Explain what a random variable is and differentiate between discrete and continuous random variables
# Ans.A random variable is a numerical outcome of a random process or experiment. It is a variable whose values depend on the outcomes of a random event. Random variables are used in probability theory and statistics to quantify uncertainty and model real-world phenomena that involve random events.
#
# Random variables can be classified into two main types: discrete and continuous.
#
# 1. Discrete Random Variables
# A discrete random variable takes on a finite or countable number of distinct values. These variables usually arise from processes where the outcomes are distinct and can be listed, often involving counts of things.
#
# Key Characteristics:
# Countable outcomes: The values the random variable can take are countable (e.g., 0, 1, 2, 3, ...).
# Examples of Discrete Random Variables:
# Number of heads in 10 coin tosses (can be 0, 1, 2, ..., 10).
# Number of cars passing through a toll booth in an hour (e.g., 3, 5, 7).
# Number of students absent in a class.
# Probability Distribution:
# The probability distribution for a discrete random variable is called the probability mass function (PMF). It assigns a probability to each possible outcome.
#
# Example: If a die is rolled, the discrete random variable
# 𝑋
# X (the outcome of the die) can take values from 1 to 6, each with a probability of
# 1
# 6
# 6
# 1
# ​
#  .
#
# 2. Continuous Random Variables
# A continuous random variable can take an infinite number of values within a given range. These variables arise from processes where the outcomes can take any value within a certain interval and are often associated with measurements.
#
# Key Characteristics:
# Uncountable outcomes: The values the random variable can take form a continuum and can’t be individually counted (e.g., any value in the interval [0, 10]).
# Examples of Continuous Random Variables:
# Height of a person (e.g., 5.6 feet, 5.61 feet, 5.611 feet, etc.).
# Time taken to run a race (e.g., 12.34 seconds, 12.345 seconds).
# Temperature in a city (e.g., 25.4°C, 25.45°C).
# Probability Distribution:
# The probability distribution for a continuous random variable is called the probability density function (PDF). Unlike discrete variables, the probability of a continuous random variable taking any specific value is zero. Instead, probabilities are determined over an interval.
#
# For continuous variables, probabilities are found using areas under the curve of the PDF, which represent the likelihood of the random variable falling within a particular range.

# %% [markdown]
# Q12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
# Ans.Let's walk through an example where we calculate both covariance and correlation for a dataset. We'll use a simple dataset of the number of hours studied and the corresponding test scores of 5 students.
#
# Example Dataset:
# Student	Hours Studied (X)	Test Score (Y)
# 1	2	65
# 2	3	70
# 3	4	75
# 4	5	80
# 5	6	85
# Step 1: Calculate the Covariance
# Covariance is a measure of the joint variability of two random variables. It tells us whether the two variables tend to increase or decrease together.
#
# The formula for covariance is:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# Cov(X,Y)=
# n
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# Where:
#
# 𝑋
# 𝑖
# X
# i
# ​
#   and
# 𝑌
# 𝑖
# Y
# i
# ​
#   are the values of the variables
# 𝑋
# X and
# 𝑌
# Y,
# 𝑋
# ˉ
# X
# ˉ
#   and
# 𝑌
# ˉ
# Y
# ˉ
#   are the means of
# 𝑋
# X and
# 𝑌
# Y,
# 𝑛
# n is the number of data points.
# Calculate the Mean of X and Y:
# 𝑋
# ˉ
# =
# 2
# +
# 3
# +
# 4
# +
# 5
# +
# 6
# 5
# =
# 20
# 5
# =
# 4
# X
# ˉ
#  =
# 5
# 2+3+4+5+6
# ​
#  =
# 5
# 20
# ​
#  =4
# 𝑌
# ˉ
# =
# 65
# +
# 70
# +
# 75
# +
# 80
# +
# 85
# 5
# =
# 375
# 5
# =
# 75
# Y
# ˉ
#  =
# 5
# 65+70+75+80+85
# ​
#  =
# 5
# 375
# ​
#  =75
# Now, calculate the covariance:
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 5
# [
# (
# 2
# −
# 4
# )
# (
# 65
# −
# 75
# )
# +
# (
# 3
# −
# 4
# )
# (
# 70
# −
# 75
# )
# +
# (
# 4
# −
# 4
# )
# (
# 75
# −
# 75
# )
# +
# (
# 5
# −
# 4
# )
# (
# 80
# −
# 75
# )
# +
# (
# 6
# −
# 4
# )
# (
# 85
# −
# 75
# )
# ]
# Cov(X,Y)=
# 5
# 1
# ​
#  [(2−4)(65−75)+(3−4)(70−75)+(4−4)(75−75)+(5−4)(80−75)+(6−4)(85−75)]
# Breaking it down:
#
# (
# 2
# −
# 4
# )
# (
# 65
# −
# 75
# )
# =
# (
# −
# 2
# )
# (
# −
# 10
# )
# =
# 20
# (2−4)(65−75)=(−2)(−10)=20
# (
# 3
# −
# 4
# )
# (
# 70
# −
# 75
# )
# =
# (
# −
# 1
# )
# (
# −
# 5
# )
# =
# 5
# (3−4)(70−75)=(−1)(−5)=5
# (
# 4
# −
# 4
# )
# (
# 75
# −
# 75
# )
# =
# (
# 0
# )
# (
# 0
# )
# =
# 0
# (4−4)(75−75)=(0)(0)=0
# (
# 5
# −
# 4
# )
# (
# 80
# −
# 75
# )
# =
# (
# 1
# )
# (
# 5
# )
# =
# 5
# (5−4)(80−75)=(1)(5)=5
# (
# 6
# −
# 4
# )
# (
# 85
# −
# 75
# )
# =
# (
# 2
# )
# (
# 10
# )
# =
# 20
# (6−4)(85−75)=(2)(10)=20
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 5
# (
# 20
# +
# 5
# +
# 0
# +
# 5
# +
# 20
# )
# =
# 50
# 5
# =
# 10
# Cov(X,Y)=
# 5
# 1
# ​
#  (20+5+0+5+20)=
# 5
# 50
# ​
#  =10
# So, the covariance is
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 10
# Cov(X,Y)=10.
#
# Step 2: Calculate the Correlation Coefficient
# The correlation coefficient (Pearson's correlation) is a normalized measure of the strength and direction of the linear relationship between two variables. It ranges from -1 to 1, where:
#
# 1
# 1 indicates a perfect positive linear relationship,
# −
# 1
# −1 indicates a perfect negative linear relationship,
# 0
# 0 indicates no linear relationship.
# The formula for the correlation coefficient
# 𝑟
# r is:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# Cov(X,Y) is the covariance between
# 𝑋
# X and
# 𝑌
# Y,
# 𝜎
# 𝑋
# σ
# X
# ​
#   is the standard deviation of
# 𝑋
# X,
# 𝜎
# 𝑌
# σ
# Y
# ​
#   is the standard deviation of
# 𝑌
# Y.
# Step 2.1: Calculate the Standard Deviations of X and Y:
# Standard deviation of X (
# 𝜎
# 𝑋
# σ
# X
# ​
#  ):
# 𝜎
# 𝑋
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# σ
# X
# ​
#  =
# n
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#
# ​
#
# 𝜎
# 𝑋
# =
# 1
# 5
# [
# (
# 2
# −
# 4
# )
# 2
# +
# (
# 3
# −
# 4
# )
# 2
# +
# (
# 4
# −
# 4
# )
# 2
# +
# (
# 5
# −
# 4
# )
# 2
# +
# (
# 6
# −
# 4
# )
# 2
# ]
# σ
# X
# ​
#  =
# 5
# 1
# ​
#  [(2−4)
# 2
#  +(3−4)
# 2
#  +(4−4)
# 2
#  +(5−4)
# 2
#  +(6−4)
# 2
#  ]
# ​
#
# 𝜎
# 𝑋
# =
# 1
# 5
# [
# 4
# +
# 1
# +
# 0
# +
# 1
# +
# 4
# ]
# =
# 10
# 5
# =
# 2
# ≈
# 1.41
# σ
# X
# ​
#  =
# 5
# 1
# ​
#  [4+1+0+1+4]
# ​
#  =
# 5
# 10
# ​
#
# ​
#  =
# 2
# ​
#  ≈1.41
# Standard deviation of Y (
# 𝜎
# 𝑌
# σ
# Y
# ​
#  ):
# 𝜎
# 𝑌
# =
# 1
# 5
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 2
# σ
# Y
# ​
#  =
# 5
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (Y
# i
# ​
#  −
# Y
# ˉ
#  )
# 2
#
# ​
#
# 𝜎
# 𝑌
# =
# 1
# 5
# [
# (
# 65
# −
# 75
# )
# 2
# +
# (
# 70
# −
# 75
# )
# 2
# +
# (
# 75
# −
# 75
# )
# 2
# +
# (
# 80
# −
# 75
# )
# 2
# +
# (
# 85
# −
# 75
# )
# 2
# ]
# σ
# Y
# ​
#  =
# 5
# 1
# ​
#  [(65−75)
# 2
#  +(70−75)
# 2
#  +(75−75)
# 2
#  +(80−75)
# 2
#  +(85−75)
# 2
#  ]
# ​
#
# 𝜎
# 𝑌
# =
# 1
# 5
# [
# 100
# +
# 25
# +
# 0
# +
# 25
# +
# 100
# ]
# =
# 250
# 5
# =
# 50
# ≈
# 7.07
# σ
# Y
# ​
#  =
# 5
# 1
# ​
#  [100+25+0+25+100]
# ​
#  =
# 5
# 250
# ​
#
# ​
#  =
# 50
# ​
#  ≈7.07
# Step 2.2: Calculate the Correlation Coefficient:
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# =
# 10
# 1.41
# ×
# 7.07
# =
# 10
# 9.97
# ≈
# 1.00
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#  =
# 1.41×7.07
# 10
# ​
#  =
# 9.97
# 10
# ​
#  ≈1.00
# So, the correlation coefficient is approximately
# 𝑟
# =
# 1.00
# r=1.00.
#
# Interpretation of Results
# Covariance: The covariance between the number of hours studied (X) and the test scores (Y) is 10. Since the covariance is positive, it indicates that as the number of hours studied increases, the test score tends to increase as well. However, covariance does not provide an easily interpretable measure of the strength of the relationship because it depends on the units of measurement.
#
# Correlation: The correlation coefficient is
# 𝑟
# =
# 1.00
# r=1.00, which suggests a perfect positive linear relationship between hours studied and test scores. In other words, for every additional hour studied, the test score increases consistently by a fixed amount.
